# %%
#obtaining top leafsubhaloid

import h5py
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import illustris_python as il
from tqdm import tqdm

def hdf5_to_dict(file_path):
    data_dict = {}
    
    with h5py.File(file_path, 'r') as hdf_file:
        # Recursively traverse the HDF5 file and populate the dictionary
        def traverse(name, obj):
            if isinstance(obj, h5py.Dataset):
                data_dict[name] = obj[()]  # Store dataset value in dictionary
            elif isinstance(obj, h5py.Group):
                # Create a nested dictionary for groups
                group_dict = {}
                data_dict[name] = group_dict
                
                # Recursively visit the group's children
                obj.visititems(traverse)
        
        hdf_file.visititems(traverse)
    
    return data_dict

# %%
#IMPORTANDO FUNCIONES PROPIAS
from particle_follower import load_counterrotating_particles
from particle_follower import load_stellar_particles
from particle_follower import filter_particles_byID
from particle_follower import generate_time_table
from particle_follower import generate_time_tables
from particle_follower import obtain_subhalo_pos

# %%
subhaloid_list = [ 455291,  478216,  501208,  531910,  547844,  570319, 571633,  582137,  589496,  598112,  606820,  619381,  628949]
subhaloid = subhaloid_list[12]
generate_time_tables(subhaloid,50,74)
# Out:
# Cargando particulas del subhalo
# Cargando particulas en snapshot 50
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 50 CONSTRUIDA
# Cargando particulas en snapshot 51
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 51 CONSTRUIDA
# Cargando particulas en snapshot 52
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 52 CONSTRUIDA
# Cargando particulas en snapshot 53
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 53 CONSTRUIDA
# Cargando particulas en snapshot 54
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 54 CONSTRUIDA
# Cargando particulas en snapshot 55
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 55 CONSTRUIDA
# Cargando particulas en snapshot 56
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 56 CONSTRUIDA
# Cargando particulas en snapshot 57
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 57 CONSTRUIDA
# Cargando particulas en snapshot 58
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 58 CONSTRUIDA
# Cargando particulas en snapshot 59
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 59 CONSTRUIDA
# Cargando particulas en snapshot 60
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 60 CONSTRUIDA
# Cargando particulas en snapshot 61
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 61 CONSTRUIDA
# Cargando particulas en snapshot 62
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 62 CONSTRUIDA
# Cargando particulas en snapshot 63
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 63 CONSTRUIDA
# Cargando particulas en snapshot 64
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 64 CONSTRUIDA
# Cargando particulas en snapshot 65
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 65 CONSTRUIDA
# Cargando particulas en snapshot 66
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 66 CONSTRUIDA
# Cargando particulas en snapshot 67
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 67 CONSTRUIDA
# Cargando particulas en snapshot 68
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 68 CONSTRUIDA
# Cargando particulas en snapshot 69
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 69 CONSTRUIDA
# Cargando particulas en snapshot 70
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 70 CONSTRUIDA
# Cargando particulas en snapshot 71
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 71 CONSTRUIDA
# Cargando particulas en snapshot 72
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 72 CONSTRUIDA
# Cargando particulas en snapshot 73
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 73 CONSTRUIDA
# Cargando particulas en snapshot 74
# Comenzando filtrado
# cambio del marco de referencia
# Tabla para particulas CR 628949 en la snapshot 74 CONSTRUIDA
# 'Tablas generadas'
